# %%
import pandas as pd
import numpy as np

# %%
dados = pd.read_csv('/content/president_heights.csv')
print(dados)
# Out:
#     order                    name  height(cm)
# 0       1       George Washington         189
# 1       2              John Adams         170
# 2       3        Thomas Jefferson         189
# 3       4           James Madison         163
# 4       5            James Monroe         183
# 5       6       John Quincy Adams         171
# 6       7          Andrew Jackson         185
# 7       8        Martin Van Buren         168
# 8       9  William Henry Harrison         173
# 9      10              John Tyler         183
# 10     11           James K. Polk         173
# 11     12          Zachary Taylor         173
# 12     13        Millard Fillmore         175
# 13     14         Franklin Pierce         178
# 14     15          James Buchanan         183
# 15     16         Abraham Lincoln         193
# 16     17          Andrew Johnson         178
# 17     18        Ulysses S. Grant         173
# 18     19     Rutherford B. Hayes         174
# ...

# %%
altura = dados['height(cm)']
print(altura)
# Out:
# 0     189
# 1     170
# 2     189
# 3     163
# 4     183
# 5     171
# 6     185
# 7     168
# 8     173
# 9     183
# 10    173
# 11    173
# 12    175
# 13    178
# 14    183
# 15    193
# 16    178
# 17    173
# 18    174
# 19    183
# 20    183
# 21    168
# 22    170
# 23    178
# 24    182
# 25    180
# 26    183
# 27    178
# 28    182
# 29    188
# 30    175
# 31    179
# 32    183
# 33    193
# 34    182
# 35    183
# 36    177
# 37    185
# 38    188
# 39    188
# 40    182
# 41    185
# Name: height(cm), dtype: int64

# %%
print("Médias das Alturas =", height.mean())
print("Desvio padrão da Altura =", height.std())
print("Altura mínima =", height.min())
print("Altura máxima =", height.max())
# Out:
# Médias das Alturas = 179.73809523809524
# Desvio padrão da Altura = 7.015868855358296
# Altura mínima = 163
# Altura máxima = 193

# %%
print("Mediana", np.median(altura))
# Out:
# Mediana 182.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
plt.hist(altura)
plt.title('Distribuição das Alturas dos Presidentes')
plt.xlabel('Altura (cm)')
plt.ylabel('Número')
plt.show()
